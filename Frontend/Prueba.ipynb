# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})

print(df)
plt.plot(df['A'], df['B'])
plt.show()
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
import pandas as pd
import matplotlib.pyplot as plt

datos = pd.DataFrame({"Mes": ["Enero", "Febrero", "Marzo", "Abril", "Mayo"],
                      "Ventas": [150, 350, 200, 150, 500]})

plt.plot(datos["Mes"], datos["Ventas"])
plt.show()
